# %%
import pandas as pd 
df=pd.read_csv('./data/bangladesh_bn_wiki_true_massive.csv')
df[df['Wikidata_ID']=='Q14565638']['Wikipedia_URL'].values[0]
# Out:
# 'https://bn.wikipedia.org/wiki/বাংলাদেশের_প্রধানমন্ত্রী'

# %%
import pandas as pd 
df=pd.read_csv('wikidata_massive_relational_map.csv')
len(df)
# Out:
# 5563
