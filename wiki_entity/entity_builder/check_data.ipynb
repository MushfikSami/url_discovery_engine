# %%
import pandas as pd 
df=pd.read_csv('bangladesh_bn_wiki_articles.csv')
len(df)
# Out:
# 332

# %%
import pandas as pd 
df=pd.read_csv('wikidata_massive_relational_map.csv')
len(df)
# Out:
# 5563
