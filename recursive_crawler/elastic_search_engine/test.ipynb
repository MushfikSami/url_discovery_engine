# %%
import pandas as pd

# %%
df1=pd.read_csv('db_all_schemas.csv')
df1.to_markdown('db_all_schemas.md', index=False)

# %%
df2=pd.read_csv('db_tables_summary.csv')
df2.to_markdown('db_tables_summary.md', index=False)
