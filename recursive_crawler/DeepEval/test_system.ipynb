# %%
import pandas as pd 
df=pd.read_csv('evaluated_queries.csv')
df.head()
# Out:
#                                              queries  \
# 0   বয়স্ক ভাতা করার ক্ষেত্রে কি জন্ম নিবন্ধন আবশ্যক?
# 1  কর্মচারী কল্যাণ তহবিল থেকে অনুদান পেতে একজন চত...
# 2        চাকরির জন্য নাগরিক সনদ নিতে কোথায় যেতে হবে?
# 3  আমার বাবা মুক্তিযোদ্ধা। মুক্তিযোদ্ধা সনদে তার ...
# 4  মুক্তিযোদ্ধা গেজেটে নাম ভুল আসলে কীভাবে সংশোধন...
#
#                                  sys_a_actual_answer  \
# 0  দুঃখিত, আমার বর্তমান ডাটাবেসে বয়স্ক ভাতা আবেদ...
# 1  System Failsafe Triggered: Agent exceeded safe...
# 2  চাকরির জন্য নাগরিক সনদ (Citizen Certificate) প...
# 3  দুঃখিত, আমার বর্তমান ডাটাবেসে মুক্তিযোদ্ধা সনদ...
# 4  মুক্তিযোদ্ধা গেজেটে নাম সংশোধন সংক্রান্ত বিষয়...
#
#                                  sys_b_actual_answer  \
# 0  দুঃখিত, আমার বর্তমান ডাটাবেসে "বয়স্ক ভাতা প্র...
# 1  বাংলাদেশ কর্মচারী কল্যাণ বোর্ড (BKKB) সরকারি ক...
# 2  চাকরির জন্য নাগরিক সনদ (Citizen Certificate) প...
# 3  দুঃখিত, আমার বর্তমান ডাটাবেসে মুক্তিযোদ্ধা সনদ...
# ...
