# %%
import pandas as pd 
df1 = pd.read_csv("webrag_benchmark_results_1.csv")
df2 = pd.read_csv("webrag_benchmark_results_2.csv")
df3 = pd.read_csv("webrag_benchmark_results_3.csv")
df4 = pd.read_csv("webrag_benchmark_results_4.csv")
df5 = pd.read_csv("webrag_benchmark_results_5.csv")
df6 = pd.read_csv("webrag_benchmark_results_6.csv")
df7 = pd.read_csv("webrag_benchmark_results_7.csv")
df8 = pd.read_csv("webrag_benchmark_results_8.csv")
df9 = pd.read_csv("webrag_benchmark_results_9.csv")
df10 = pd.read_csv("webrag_benchmark_results_10.csv")

# %%
df_all = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)
df_all.to_csv("webrag_benchmark_results_all.csv", index=False)
# Out:
#              Timestamp                               Original_Query  \
# 0  2026-05-20 14:42:39       When was Dhaka University established?
# 1  2026-05-20 14:42:46  Who is the current President of Bangladesh?
# 2  2026-05-20 14:42:51   What is the national flower of Bangladesh?
# 3  2026-05-20 14:42:57              Tell me about the Padma Bridge.
# 4  2026-05-20 14:43:03             Where is the Sundarbans located?
#
#                     Optimized_Query  \
# 0               University of Dhaka
# 1  List of presidents of Bangladesh
# 2     National flower of Bangladesh
# 3                      Padma Bridge
# 4                        Sundarbans
#
#                                           Target_URL  Fanout_Time_sec  \
# 0  https://en.wikipedia.org/wiki/University_of_Dhaka            0.159
# 1  https://en.wikipedia.org/wiki/List_of_presiden...            0.089
# 2   https://en.wikipedia.org/wiki/Nymphaea_pubescens            0.081
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Timestamp, Original_Query, Optimized_Query, Target_URL, Fanout_Time_sec, Search_Time_sec, Parse_Time_sec, Total_Time_sec, Markdown_Length, Status]
# Index: []
